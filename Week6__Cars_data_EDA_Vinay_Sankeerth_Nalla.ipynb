# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinaysankeerth13/Cars-data-analysis-/blob/main/Week6__Cars_data_EDA_Vinay_Sankeerth_Nalla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem Statement (by self):
#
# * Find out in which budget range can a customer purchase a car without compromising on safety features.
#
# * Make a comprehensive analysis on the top three companies according to sales.

# %% [markdown]
# # Importing the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Week 6 D A internship/cars_ds_final.csv",index_col=0)

# %% [markdown]
# # Primary look into the data

# %%
df.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1276 entries, 0 to 1275
# Columns: 140 entries, Make to Electric_Range
# dtypes: float64(6), object(134)
# memory usage: 1.4+ MB

# %%
df.info
# Out:
# <bound method DataFrame.info of             Make      Model        Variant Ex-Showroom_Price Displacement  \
# 0           Tata  Nano Genx             Xt      Rs. 2,92,667       624 cc
# 1           Tata  Nano Genx             Xe      Rs. 2,36,447       624 cc
# 2           Tata  Nano Genx        Emax Xm      Rs. 2,96,661       624 cc
# 3           Tata  Nano Genx            Xta      Rs. 3,34,768       624 cc
# 4           Tata  Nano Genx             Xm      Rs. 2,72,223       624 cc
# ...          ...        ...            ...               ...          ...
# 1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000      1498 cc
# 1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000      1498 cc
# 1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000      1497 cc
# 1274       Honda       City   V Cvt Petrol     Rs. 12,01,000      1497 cc
# 1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560      3200 cc
#
# ...

# %%
df.shape
# Out:
# (1276, 140)

# %%
df.isna().sum()
# Out:
# Make                   75
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
# Displacement           12
#                      ...
# USB_Ports            1247
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 140, dtype: int64

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Variant', 'Ex-Showroom_Price', 'Displacement',
#        'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration', 'Emission_Norm',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=140)

# %%
df.rename(columns = str.lower,inplace=True)
df.columns
# Out:
# Index(['make', 'model', 'variant', 'ex-showroom_price', 'displacement',
#        'cylinders', 'valves_per_cylinder', 'drivetrain',
#        'cylinder_configuration', 'emission_norm',
#        ...
#        'leather_wrapped_steering', 'automatic_headlamps', 'engine_type',
#        'asr_/_traction_control', 'cruise_control', 'usb_ports',
#        'heads-up_display', 'welcome_lights', 'battery', 'electric_range'],
#       dtype='object', length=140)

# %% [markdown]
# # Data Segregation and Cleaning

# %% [markdown]
# ['make','model','ex-showroom_price','body_type','displacement', 'cylinders', 'fuel_system', 'fuel_tank_capacity', 'fuel_type',  'city_mileage',  'seating_capacity','basic_warranty', 'child_safety_locks', 'number_of_airbags', 'parking_assistance',  'navigation_system']

# %%
new_df = df[['make','model','ex-showroom_price','body_type','displacement', 'cylinders', 'fuel_system', 'fuel_tank_capacity', 'fuel_type',  'city_mileage',  'seating_capacity','basic_warranty', 'child_safety_locks', 'number_of_airbags', 'parking_assistance',  'navigation_system']]

# %%
new_df.shape
# Out:
# (1276, 16)

# %%
new_df.isna().sum()
# Out:
# make                   75
# model                   0
# ex-showroom_price       0
# body_type               6
# displacement           12
# cylinders              66
# fuel_system             8
# fuel_tank_capacity     69
# fuel_type               0
# city_mileage          555
# seating_capacity        6
# basic_warranty        440
# child_safety_locks     75
# number_of_airbags     135
# parking_assistance    290
# navigation_system     593
# dtype: int64

# %%
new_df.head()
# Out:
#    make      model ex-showroom_price  body_type displacement  cylinders  \
# 0  Tata  Nano Genx      Rs. 2,92,667  Hatchback       624 cc        2.0
# 1  Tata  Nano Genx      Rs. 2,36,447  Hatchback       624 cc        2.0
# 2  Tata  Nano Genx      Rs. 2,96,661  Hatchback       624 cc        2.0
# 3  Tata  Nano Genx      Rs. 3,34,768  Hatchback       624 cc        2.0
# 4  Tata  Nano Genx      Rs. 2,72,223  Hatchback       624 cc        2.0
#
#   fuel_system fuel_tank_capacity fuel_type    city_mileage  seating_capacity  \
# 0   Injection          24 litres    Petrol  ?23.6 km/litre               4.0
# 1   Injection          24 litres    Petrol  ?23.6 km/litre               4.0
# 2   Injection          15 litres       CNG             NaN               4.0
# 3   Injection          24 litres    Petrol  ?23.6 km/litre               4.0
# 4   Injection          24 litres    Petrol  ?23.6 km/litre               4.0
#
# ...

# %%
new_df['navigation_system'].fillna('No', inplace=True)
# Out:
# <ipython-input-15-277ee0056045>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['navigation_system'].fillna('No', inplace=True)

# %%
new_df['navigation_system'].value_counts()
# Out:
# Yes    683
# No     593
# Name: navigation_system, dtype: int64

# %%
new_df['parking_assistance'].value_counts()
# Out:
# Rear sensors with camera                                                         367
# Rear sensors                                                                     277
# Front and rear sensors with camera                                               181
# Front & rear sensors with 360 degree view                                        120
# Rear sensors, Rear sensors with camera                                            17
# Yes                                                                               15
# Front sensors, Rear sensors                                                        5
# Front and rear sensors with camera, Front & rear sensors with 360 degree view      2
# Rear sensors with camera, Rear sensors                                             1
# Rear sensors, Front sensors                                                        1
# Name: parking_assistance, dtype: int64

# %%
new_df['parking_assistance'].fillna('No', inplace=True)
# Out:
# <ipython-input-18-9fe40478833e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['parking_assistance'].fillna('No', inplace=True)

# %%
new_df['parking_assistance'].value_counts()
# Out:
# Rear sensors with camera                                                         367
# No                                                                               290
# Rear sensors                                                                     277
# Front and rear sensors with camera                                               181
# Front & rear sensors with 360 degree view                                        120
# Rear sensors, Rear sensors with camera                                            17
# Yes                                                                               15
# Front sensors, Rear sensors                                                        5
# Front and rear sensors with camera, Front & rear sensors with 360 degree view      2
# Rear sensors with camera, Rear sensors                                             1
# Rear sensors, Front sensors                                                        1
# Name: parking_assistance, dtype: int64

# %%
new_df['city_mileage'].value_counts()
# Out:
# 12 km/litre      38
# 16 km/litre      30
# 18 km/litre      26
# 14 km/litre      20
# 23 km/litre      19
#                  ..
# 8.69 km/litre     1
# 4 km/litre        1
# 3 km/litre        1
# 4.38 km/litre     1
# 8.25 km/litre     1
# Name: city_mileage, Length: 164, dtype: int64

# %%
new_df[new_df['city_mileage'].isna()]
# Out:
#                make              model ex-showroom_price  body_type  \
# 2              Tata          Nano Genx      Rs. 2,96,661  Hatchback
# 10           Datsun            Redi-Go      Rs. 3,90,000  Hatchback
# 11           Datsun            Redi-Go      Rs. 4,37,065  Hatchback
# 27    Maruti Suzuki               Eeco      Rs. 4,66,057        MPV
# 28    Maruti Suzuki               Eeco      Rs. 4,25,255        MPV
# ...             ...                ...               ...        ...
# 1250          Skoda            Octavia     Rs. 21,99,599      Sedan
# 1251            NaN  Mercedes-Benz Glc     Rs. 52,75,000        SUV
# 1252            NaN  Mercedes-Benz Glc     Rs. 57,75,000        SUV
# 1253        Porsche      Cayenne Coupe   Rs. 1,31,51,000        NaN
# 1254        Porsche      Cayenne Coupe   Rs. 1,97,63,000        NaN
#
#      displacement  cylinders fuel_system fuel_tank_capacity fuel_type  \
# 2          624 cc        2.0   Injection          15 litres       CNG
# ...

# %%
nan_counts = new_df.groupby('model')['city_mileage'].apply(lambda x: x.isna().sum())
nan_counts_sorted = nan_counts.sort_values(ascending=False)
nan_counts_sorted
# Out:
# model
# Nexon                    24
# Compass                  21
# Amaze                    20
# Seltos                   16
# Wagon                    14
#                          ..
# Monte Carlo               0
# Montero                   0
# Mu-X                      0
# Mulsanne                  0
# Mercedes-Benz A-Class     0
# Name: city_mileage, Length: 263, dtype: int64

# %%
new_df.loc[df['model'] == 'Civic', 'city_mileage'] = '16.5 km/litre'
new_df.loc[df['model'] == 'Ls 500H', 'city_mileage'] = '15 km/litre'
new_df.loc[df['model'] == 'Rs5', 'city_mileage'] = '8.8 km/litre'
new_df.loc[df['model'] == 'Mercedes-Benz Amg Gt 4-Door Coupe', 'city_mileage'] = '12.6 km/litre'
new_df.loc[df['model'] == '812 Superfast', 'city_mileage'] = '6.7 km/litre'
new_df.loc[df['model'] == 'Rolls-Royce Cullinan', 'city_mileage'] = '9.5 km/litre'
new_df.loc[df['model'] == 'S60', 'city_mileage'] = '14 km/litre'
new_df.loc[df['model'] == 'Mercedes-Benz E-Class All Terrain', 'city_mileage'] = '12.5 km/litre'
new_df.loc[df['model'] == 'Mercedes-Benz C-Class Cabriolet', 'city_mileage'] = '17.4 km/litre'
new_df.loc[df['model'] == 'Bentayga', 'city_mileage'] = '8.6 km/litre'
new_df.loc[df['model'] == 'Xc90', 'city_mileage'] = '17.2 km/litre'
new_df.loc[df['model'] == 'A5 Cabriolet', 'city_mileage'] = '14.1 km/litre'
new_df.loc[df['model'] == 'Grand I10', 'city_mileage'] = '17.6 km/litre'
new_df.loc[df['model'] == 'Mercedes-Benz Maybach', 'city_mileage'] = '7.5 km/litre'
new_df.loc[df['model'] == 'S5', 'city_mileage'] = '10.6 km/litre'
new_df.loc[df['model'] == 'Convertible', 'city_mileage'] = '17 km/litre'
new_df.loc[df['model'] == 'X1', 'city_mileage'] = '16.35 km/litre'
new_df.loc[df['model'] == 'Grand Cherokee', 'city_mileage'] = '8.6 km/litre'
new_df.loc[df['model'] == 'Celerio', 'city_mileage'] = '23 km/litre'
new_df.loc[df['model'] == 'F-Pace', 'city_mileage'] = '13 km/litre'
new_df.loc[df['model'] == 'Kodiaq Scout', 'city_mileage'] = '13 km/litre'
new_df.loc[df['model'] == 'Q8', 'city_mileage'] = '10 km/litre'
new_df.loc[df['model'] == 'Lc 500H', 'city_mileage'] = '12.3 km/litre'
new_df.loc[df['model'] == 'Mercedes-Benz Cls', 'city_mileage'] = '9 km/litre'
new_df.loc[df['model'] == 'A8 L', 'city_mileage'] = '12.3 km/litre'
new_df.loc[df['model'] == 'Punto Evo Pure', 'city_mileage'] = '16 km/litre'
new_df.loc[df['model'] == 'Urus', 'city_mileage'] = '5 km/litre'
new_df.loc[df['model'] == 'John Cooper Works', 'city_mileage'] = '17 km/litre'
new_df.loc[df['model'] == 'Discovery Sport', 'city_mileage'] = '19.5 km/litre'
new_df.loc[df['model'] == 'A6', 'city_mileage'] = '13.5 km/litre'
new_df.loc[df['model'] == 'A4', 'city_mileage'] = '16 km/litre'
new_df.loc[df['model'] == 'Gtc4 Lusso', 'city_mileage'] = '9 km/litre'
new_df.loc[df['model'] == 'Rolls-Royce Ghost Series Ii', 'city_mileage'] = '4.5 km/litre'
new_df.loc[df['model'] == 'Qute (Re60)', 'city_mileage'] = '43 km/litre'
new_df.loc[df['model'] == 'Nx 300H', 'city_mileage'] = '18 km/litre'
new_df.loc[df['model'] == 'Z4 Roadster', 'city_mileage'] = '11 km/litre'
new_df.loc[df['model'] == 'Mercedes-Benz G-Class', 'city_mileage'] = '6 km/litre'
new_df.loc[df['model'] == 'Xuv500', 'city_mileage'] = '11.5 km/litre'
new_df.loc[df['model'] == 'Mercedes-Benz Gle', 'city_mileage'] = '9 km/litre'
new_df.loc[df['model'] == 'Grand I10 Prime', 'city_mileage'] = '17 km/litre'
new_df.loc[df['model'] == 'Chiron', 'city_mileage'] = '4.5 km/litre'
new_df.loc[df['model'] == 'Tiguan', 'city_mileage'] = '9 km/litre'
new_df.loc[df['model'] == 'Gurkha', 'city_mileage'] = '17 km/litre'
new_df.loc[df['model'] == 'Q7', 'city_mileage'] = '11 km/litre'
new_df.loc[df['model'] == 'Xc40', 'city_mileage'] = '12 km/litre'
new_df.loc[df['model'] == 'Q5', 'city_mileage'] = '13.5 km/litre'
new_df.loc[df['model'] == 'X7', 'city_mileage'] = '11.3 km/litre'
new_df.loc[df['model'] == 'Cooper 3 Door', 'city_mileage'] = '17 km/litre'
new_df.loc[df['model'] == 'Ghibli', 'city_mileage'] = '8 km/litre'
new_df.loc[df['model'] == 'X5', 'city_mileage'] = '12 km/litre'
new_df.loc[df['model'] == 'Mercedes-Benz E-Class', 'city_mileage'] = '15 km/litre'
new_df.loc[df['model'] == '7-Series', 'city_mileage'] = '13 km/litre'
new_df.loc[df['model'] == 'Nexon Ev', 'city_mileage'] = 'NaN'
new_df.loc[df['model'] == 'Tigor Ev', 'city_mileage'] = 'NaN'
new_df.loc[df['model'] == 'Kona Electric', 'city_mileage'] = 'NaN'
new_df.loc[df['model'] == 'Zs Ev', 'city_mileage'] = 'NaN'
new_df.loc[df['model'] == '3-Series', 'city_mileage'] = '13 km/litre'
new_df.loc[df['model'] == 'X4', 'city_mileage'] = '13 km/litre'
new_df.loc[df['model'] == 'Mercedes-Benz V-Class', 'city_mileage'] = '16 km/litre'
new_df.loc[df['model'] == 'Cayenne', 'city_mileage'] = '11 km/litre'
new_df.loc[df['model'] == 'Passat', 'city_mileage'] = '17 km/litre'
new_df.loc[df['model'] == 'Captur', 'city_mileage'] = '14 km/litre'
new_df.loc[df['model'] == 'Range Evoque', 'city_mileage'] = '11 km/litre'
new_df.loc[df['model'] == 'Thar', 'city_mileage'] = '14 km/litre'
new_df.loc[df['model'] == 'Cr-V', 'city_mileage'] = '12 km/litre'
new_df.loc[df['model'] == 'Range', 'city_mileage'] = '9 km/litre'
new_df.loc[df['model'] == 'Countryman', 'city_mileage'] = '14.5 km/litre'
new_df.loc[df['model'] == 'Xl6', 'city_mileage'] = '16 km/litre'
new_df.loc[df['model'] == 'Xe', 'city_mileage'] = '18 km/litre'
new_df.loc[df['model'] == 'Alto', 'city_mileage'] = '17.5 km/litre'
new_df.loc[df['model'] == 'Marazzo', 'city_mileage'] = '15 km/litre'
new_df.loc[df['model'] == 'Mercedes-Benz C-Class', 'city_mileage'] = '17 km/litre'
new_df.loc[df['model'] == 'Figo', 'city_mileage'] = '15.5 km/litre'
new_df.loc[df['model'] == 'Carnival', 'city_mileage'] = '14 km/litre'
new_df.loc[df['model'] == 'Ertiga', 'city_mileage'] = '16 km/litre'
new_df.loc[df['model'] == 'S-Presso', 'city_mileage'] = '17 km/litre'
new_df.loc[df['model'] == 'Vento', 'city_mileage'] = '14.5 km/litre'
new_df.loc[df['model'] == 'Range Sport', 'city_mileage'] = '11 km/litre'
new_df.loc[df['model'] == 'Verna', 'city_mileage'] = '19 km/litre'
new_df.loc[df['model'] == 'Swift', 'city_mileage'] = '19 km/litre'
new_df.loc[df['model'] == 'Ecosport', 'city_mileage'] = '13 km/litre'
new_df.loc[df['model'] == 'Hector', 'city_mileage'] = '10 km/litre'
new_df.loc[df['model'] == 'Xuv300', 'city_mileage'] = '16 km/litre'
new_df.loc[df['model'] == 'Altroz', 'city_mileage'] = '18.5 km/litre'
new_df.loc[df['model'] == 'Nexon', 'city_mileage'] = '16 km/litre'
new_df.loc[df['model'] == 'Compass', 'city_mileage'] = '14 km/litre'
new_df.loc[df['model'] == 'Amaze', 'city_mileage'] = '14 km/litre'
new_df.loc[df['model'] == 'Seltos', 'city_mileage'] = '11 km/litre'
new_df.loc[df['model'] == 'Venue', 'city_mileage'] = '11 km/litre'
new_df.loc[df['model'] == 'Nano Genx', 'city_mileage'] = '16 km/litre'
new_df.loc[df['model'] == 'Redi-Go', 'city_mileage'] = '13 km/litre'
new_df.loc[df['model'] == 'Eeco', 'city_mileage'] = '14 km/litre'
new_df.loc[df['model'] == 'Octavia', 'city_mileage'] = '12.5 km/litre'
new_df.loc[df['model'] == 'Mercedes-Benz Glc', 'city_mileage'] = '12 km/litre'
new_df.loc[df['model'] == 'Cayenne Coupe', 'city_mileage'] = '9 km/litre'
new_df.loc[df['model'] == 'Go', 'city_mileage'] = '12 km/litre'
new_df.loc[df['model'] == 'Alto K10', 'city_mileage'] = '20 km/litre'
new_df.loc[df['model'] == 'Yaris', 'city_mileage'] = '15.5 km/litre'
new_df.loc[df['model'] == 'Celerio Tour', 'city_mileage'] = '23 km/litre'
new_df.loc[df['model'] == 'Santro', 'city_mileage'] = '17 km/litre'
new_df.loc[df['model'] == 'Discovery', 'city_mileage'] = '7 km/litre'
new_df.loc[df['model'] == 'Tiago', 'city_mileage'] = '19 km/litre'
new_df.loc[df['model'] == 'Triber', 'city_mileage'] = '8 km/litre'
new_df.loc[df['model'] == 'Kicks', 'city_mileage'] = '12 km/litre'
new_df.loc[df['model'] == 'Winger', 'city_mileage'] = '11 km/litre'
new_df.loc[df['model'] == 'Camry', 'city_mileage'] = '13 km/litre'
new_df.loc[df['model'] == 'A5', 'city_mileage'] = '14 km/litre'
new_df.loc[df['model'] == 'Micra Active', 'city_mileage'] = '12 km/litre'
new_df.loc[df['model'] == 'Xcent Prime', 'city_mileage'] = '16 km/litre'
new_df.loc[df['model'] == 'Wagon', 'city_mileage'] = '18 km/litre'
new_df.loc[df['model'] == 'Tiago Nrg', 'city_mileage'] = '19 km/litre'
new_df.loc[df['model'] == 'Dzire Tour', 'city_mileage'] = '20 km/litre'
new_df.loc[df['model'] == 'Aura', 'city_mileage'] = '14 km/litre'
new_df.loc[df['model'] == 'F-Type', 'city_mileage'] = '9 km/litre'
new_df.loc[df['model'] == 'M5', 'city_mileage'] = '9 km/litre'
new_df.loc[df['model'] == 'Freestyle', 'city_mileage'] = '10.5 km/litre'
new_df.loc[df['model'] == '6-Series', 'city_mileage'] = '13 km/litre'
new_df.loc[df['model'] == 'Macan', 'city_mileage'] = '12 km/litre'
new_df.loc[df['model'] == 'Ameo', 'city_mileage'] = '16 km/litre'
new_df.loc[df['model'] == 'Aspire', 'city_mileage'] = '12 km/litre'
new_df.loc[df['model'] == 'Harrier', 'city_mileage'] = '14 km/litre'
new_df.loc[df['model'] == 'Harrier', 'body_type'] = 'SUV'
new_df.loc[df['model'] == 'Outlander', 'city_mileage'] = '16 km/litre'
new_df.loc[df['model'] == 'Glanza', 'city_mileage'] = '14 km/litre'
new_df.loc[df['model'] == 'Ciaz', 'city_mileage'] = '14 km/litre'
new_df.loc[df['model'] == 'Creta', 'city_mileage'] = '18 km/litre'
new_df.loc[df['model'] == 'Jazz', 'city_mileage'] = '12 km/litre'
new_df.loc[df['model'] == 'Compass Trailhawk', 'city_mileage'] = '12 km/litre'
new_df.loc[df['model'] == 'Alturas G4', 'city_mileage'] = '8 km/litre'
new_df.loc[df['model'] == 'Grand I10 Nios', 'city_mileage'] = '12 km/litre'
new_df.loc[df['model'] == 'Micra', 'city_mileage'] = '12 km/litre'

# %%
new_df[new_df['city_mileage'].isna()]
# Out:
# Empty DataFrame
# Columns: [make, model, ex-showroom_price, body_type, displacement, cylinders, fuel_system, fuel_tank_capacity, fuel_type, city_mileage, seating_capacity, basic_warranty, child_safety_locks, number_of_airbags, parking_assistance, navigation_system]
# Index: []

# %%
new_df.isna().sum()
# Out:
# make                   75
# model                   0
# ex-showroom_price       0
# body_type               6
# displacement           12
# cylinders              66
# fuel_system             8
# fuel_tank_capacity     69
# fuel_type               0
# city_mileage            0
# seating_capacity        6
# basic_warranty        440
# child_safety_locks     75
# number_of_airbags     135
# parking_assistance      0
# navigation_system       0
# dtype: int64

# %%
new_df['basic_warranty'].value_counts()
# Out:
# 2 years / Unlimited Kms                                            132
# 3 years / Unlimited Kms                                            118
# 2 years /40000 Kms (years/distance whichever comes first)          110
# 3 years /100000 Kms (years/distance whichever comes first)          85
# 3 Years/1,00,000 Kms (Whichever comes earlier)                      77
# 2 Years / 40,000 Kms (Whichever comes earlier)                      54
# 2 Years / 100,000 Kms (whichever comes first)                       51
# 2 years /75000 Kms (years/distance whichever comes first)           31
# 2 years /1,00,000 Kms (years/distance whichever comes first)        30
# 24 months /50000 Kms (whichever comes first)                        20
# 2 years /50000 Kms (years/distance whichever comes first)           18
# 2 Years / 75,000 KM (whichever is earlier)                          17
# 2 Years / 50,000 Kms (Whichever comes earlier)                      16
# ...

# %%
new_df['basic_warranty'].fillna('No',inplace=True)
# Out:
# <ipython-input-27-262973ce95b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['basic_warranty'].fillna('No',inplace=True)

# %%
new_df.isna().sum()
# Out:
# make                   75
# model                   0
# ex-showroom_price       0
# body_type               6
# displacement           12
# cylinders              66
# fuel_system             8
# fuel_tank_capacity     69
# fuel_type               0
# city_mileage            0
# seating_capacity        6
# basic_warranty          0
# child_safety_locks     75
# number_of_airbags     135
# parking_assistance      0
# navigation_system       0
# dtype: int64

# %%
new_df['number_of_airbags'].value_counts()
# Out:
# 2.0     627
# 6.0     202
# 8.0      92
# 7.0      65
# 1.0      57
# 4.0      40
# 9.0      21
# 3.0      17
# 10.0     16
# 14.0      3
# 5.0       1
# Name: number_of_airbags, dtype: int64

# %%
new_df['number_of_airbags'].fillna(0,inplace=True)
# Out:
# <ipython-input-30-2646f36fbf32>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['number_of_airbags'].fillna(0,inplace=True)

# %%
new_df['number_of_airbags'].value_counts()
# Out:
# 2.0     627
# 6.0     202
# 0.0     135
# 8.0      92
# 7.0      65
# 1.0      57
# 4.0      40
# 9.0      21
# 3.0      17
# 10.0     16
# 14.0      3
# 5.0       1
# Name: number_of_airbags, dtype: int64

# %%
new_df.isna().sum()
# Out:
# make                  75
# model                  0
# ex-showroom_price      0
# body_type              6
# displacement          12
# cylinders             66
# fuel_system            8
# fuel_tank_capacity    69
# fuel_type              0
# city_mileage           0
# seating_capacity       6
# basic_warranty         0
# child_safety_locks    75
# number_of_airbags      0
# parking_assistance     0
# navigation_system      0
# dtype: int64

# %%
new_df['child_safety_locks'].value_counts()
# Out:
# Yes    1201
# Name: child_safety_locks, dtype: int64

# %%
new_df['child_safety_locks'].fillna('No',inplace=True)
# Out:
# <ipython-input-34-29e12a48ceba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['child_safety_locks'].fillna('No',inplace=True)

# %%
new_df.isna().sum()
# Out:
# make                  75
# model                  0
# ex-showroom_price      0
# body_type              6
# displacement          12
# cylinders             66
# fuel_system            8
# fuel_tank_capacity    69
# fuel_type              0
# city_mileage           0
# seating_capacity       6
# basic_warranty         0
# child_safety_locks     0
# number_of_airbags      0
# parking_assistance     0
# navigation_system      0
# dtype: int64

# %%
new_df['fuel_tank_capacity'].value_counts()
# Out:
# 45 litres      125
# 35 litres      124
# 50 litres       94
# 60 litres       91
# 37 litres       79
#               ...
# 36 litres        1
# 90.5 litres      1
# 87 litres        1
# 72 litres        1
# 96 litres        1
# Name: fuel_tank_capacity, Length: 63, dtype: int64

# %%
nan_counts2 = new_df.groupby('model')['fuel_tank_capacity'].apply(lambda x: x.isna().sum())
nan_counts2
# Out:
# model
# 3-Series        0
# 458 Speciale    0
# 458 Spider      0
# 488 Gtb         0
# 5-Series        0
#                ..
# Xylo            0
# Yaris           0
# Z4 Roadster     0
# Zest            0
# Zs Ev           2
# Name: fuel_tank_capacity, Length: 263, dtype: int64

# %%
new_df[new_df['fuel_tank_capacity'].isna()]
# Out:
#           make          model ex-showroom_price    body_type displacement  \
# 269      Volvo           Xc40     Rs. 39,90,000          SUV      1969 cc
# 270      Volvo           Xc40     Rs. 43,90,000          SUV      1969 cc
# 272       Mini        Clubman     Rs. 41,20,000    Hatchback      1998 cc
# 293      Volvo            S90     Rs. 58,90,000        Sedan      1969 cc
# 295        Bmw             X5     Rs. 73,30,000          SUV      2993 cc
# ...        ...            ...               ...          ...          ...
# 1144     Isuzu   Dmax V-Cross     Rs. 19,99,000      Pick-up      1898 cc
# 1162    Jaguar         F-Type   Rs. 2,36,59,454  Convertible      5000 cc
# 1193  Mahindra      Nuvosport      Rs. 8,32,415          SUV      1493 cc
# 1205   Hyundai  Kona Electric     Rs. 23,71,858          SUV          NaN
# 1207      Audi             A5     Rs. 60,61,200        Sedan      1968 cc
#
#       cylinders fuel_system fuel_tank_capacity fuel_type    city_mileage  \
# ...

# %%
new_df.loc[df['model'] == 'Range Velar', 'fuel_tank_capacity'] = '60-82 litres'
new_df.loc[df['model'] == 'Huracan', 'fuel_tank_capacity'] = '80 litres'
new_df.loc[df['model'] == 'Es', 'fuel_tank_capacity'] = '65 litres'
new_df.loc[df['model'] == 'Mercedes-Benz Cls', 'fuel_tank_capacity'] = '66 litres'
new_df.loc[df['model'] == 'Abarth Punto', 'fuel_tank_capacity'] = '45 litres'
new_df.loc[df['model'] == 'Hexa', 'fuel_tank_capacity'] = '60 litres'
new_df.loc[df['model'] == 'S90', 'fuel_tank_capacity'] = '60 litres'
new_df.loc[df['model'] == 'Rolls-Royce Cullinan', 'fuel_tank_capacity'] = '100 litres'
new_df.loc[df['model'] == 'Abarth Avventura', 'fuel_tank_capacity'] = '45 litres'
new_df.loc[df['model'] == 'Range Evoque Convertible', 'fuel_tank_capacity'] = '54 litres'
new_df.loc[df['model'] == 'Chiron', 'fuel_tank_capacity'] = '100 litres'
new_df.loc[df['model'] == 'Qute (Re60)', 'fuel_tank_capacity'] = '35 litres'
new_df.loc[df['model'] == 'Range Sport', 'fuel_tank_capacity'] = '86 litres'
new_df.loc[df['model'] == 'E2O Plus', 'fuel_tank_capacity'] = '0 litres'
new_df.loc[df['model'] == 'Nexon Ev', 'fuel_tank_capacity'] = '0 litres'
new_df.loc[df['model'] == 'Kona Electric', 'fuel_tank_capacity'] = '0 litres'
new_df.loc[df['model'] == 'Zs Ev', 'fuel_tank_capacity'] = '0 litres'
new_df.loc[df['model'] == 'E Verito', 'fuel_tank_capacity'] = '0 litres'
new_df.loc[df['model'] == 'Xc40', 'fuel_tank_capacity'] = '54 litres'
new_df.loc[df['model'] == 'Clubman', 'fuel_tank_capacity'] = '48 litres'
new_df.loc[df['model'] == 'X5', 'fuel_tank_capacity'] = '83 litres'
new_df.loc[df['model'] == 'Dmax V-Cross', 'fuel_tank_capacity'] = '55 litres'
new_df.loc[df['model'] == 'F-Type', 'fuel_tank_capacity'] = '70 litres'
new_df.loc[df['model'] == 'Nuvosport', 'fuel_tank_capacity'] = '60 litres'
new_df.loc[df['model'] == 'A5', 'fuel_tank_capacity'] = '58 litres'
new_df.loc[df['model'] == 'Carnival', 'fuel_tank_capacity'] = '60 litres'
new_df.loc[df['model'] == 'Range Evoque', 'fuel_tank_capacity'] = '67 litres'
new_df.loc[df['model'] == 'Range', 'fuel_tank_capacity'] = '85 litres'
new_df.loc[df['model'] == 'Hector', 'fuel_tank_capacity'] = '60 litres'
new_df.loc[df['model'] == 'Venue', 'fuel_tank_capacity'] = '45 litres'

# %%
new_df.isna().sum()
# Out:
# make                  75
# model                  0
# ex-showroom_price      0
# body_type              6
# displacement          12
# cylinders             66
# fuel_system            8
# fuel_tank_capacity     0
# fuel_type              0
# city_mileage           0
# seating_capacity       6
# basic_warranty         0
# child_safety_locks     0
# number_of_airbags      0
# parking_assistance     0
# navigation_system      0
# dtype: int64

# %%
new_df['cylinders'].value_counts()
# Out:
# 4.0     789
# 3.0     213
# 6.0     106
# 8.0      53
# 12.0     21
# 5.0      10
# 10.0     10
# 2.0       6
# 16.0      2
# Name: cylinders, dtype: int64

# %%
new_df['cylinders'].fillna(0,inplace=True)
# Out:
# <ipython-input-42-7691bcece0a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['cylinders'].fillna(0,inplace=True)

# %%
new_df['cylinders'].value_counts()
# Out:
# 4.0     789
# 3.0     213
# 6.0     106
# 0.0      66
# 8.0      53
# 12.0     21
# 5.0      10
# 10.0     10
# 2.0       6
# 16.0      2
# Name: cylinders, dtype: int64

# %%
new_df.isna().sum()
# Out:
# make                  75
# model                  0
# ex-showroom_price      0
# body_type              6
# displacement          12
# cylinders              0
# fuel_system            8
# fuel_tank_capacity     0
# fuel_type              0
# city_mileage           0
# seating_capacity       6
# basic_warranty         0
# child_safety_locks     0
# number_of_airbags      0
# parking_assistance     0
# navigation_system      0
# dtype: int64

# %%
new_df['seating_capacity'].value_counts()
# Out:
# 5.0     915
# 7.0     183
# 4.0      70
# 2.0      39
# 6.0      26
# 9.0      19
# 8.0      17
# 16.0      1
# Name: seating_capacity, dtype: int64

# %%
new_df[new_df['seating_capacity'].isna()]
# Out:
#             make          model ex-showroom_price    body_type displacement  \
# 239     Mahindra     Alturas G4     Rs. 27,70,150          NaN      2157 cc
# 242   Volkswagen         Tiguan     Rs. 31,53,500          SUV      1968 cc
# 598      Renault          Lodgy     Rs. 12,11,599          MUV      1461 cc
# 1162      Jaguar         F-Type   Rs. 2,36,59,454  Convertible      5000 cc
# 1253     Porsche  Cayenne Coupe   Rs. 1,31,51,000          NaN      2995 cc
# 1254     Porsche  Cayenne Coupe   Rs. 1,97,63,000          NaN      2995 cc
#
#       cylinders fuel_system fuel_tank_capacity fuel_type    city_mileage  \
# 239         4.0   Injection          70 litres    Diesel      8 km/litre
# 242         4.0   Injection          71 litres    Diesel      9 km/litre
# 598         4.0   Injection          50 litres    Diesel  21.04 km/litre
# 1162        0.0         NaN          70 litres    Petrol      9 km/litre
# ...

# %%
seating_capacity_dtype = df['seating_capacity'].dtype
seating_capacity_dtype
# Out:
# dtype('float64')

# %%
new_df.loc[df['model'] == 'Alturas G4', 'seating_capacity'] = 7
new_df.loc[df['model'] == 'Tiguan', 'seating_capacity'] = 7
new_df.loc[df['model'] == 'Lodgy', 'seating_capacity'] = 7
new_df.loc[df['model'] == 'F-Type', 'seating_capacity'] = 2
new_df.loc[df['model'] == 'Cayenne Coupe', 'seating_capacity'] = 4

# %%
new_df.isna().sum()
# Out:
# make                  75
# model                  0
# ex-showroom_price      0
# body_type              6
# displacement          12
# cylinders              0
# fuel_system            8
# fuel_tank_capacity     0
# fuel_type              0
# city_mileage           0
# seating_capacity       0
# basic_warranty         0
# child_safety_locks     0
# number_of_airbags      0
# parking_assistance     0
# navigation_system      0
# dtype: int64

# %%
new_df['fuel_system'].value_counts()
# Out:
# Injection    1264
# PGM - Fi        4
# Name: fuel_system, dtype: int64

# %%
new_df[new_df['fuel_system'].isna()]
# Out:
#                   make          model ex-showroom_price    body_type  \
# 687           Mahindra       E Verito     Rs. 12,93,214        Sedan
# 688           Mahindra       E Verito     Rs. 12,67,208        Sedan
# 689           Mahindra       E Verito     Rs. 13,03,241        Sedan
# 827   Land Rover Rover    Range Sport   Rs. 2,05,17,853          SUV
# 833   Land Rover Rover    Range Sport   Rs. 1,79,40,227          SUV
# 1145        Mitsubishi      Outlander     Rs. 26,93,000          SUV
# 1162            Jaguar         F-Type   Rs. 2,36,59,454  Convertible
# 1205           Hyundai  Kona Electric     Rs. 23,71,858          SUV
#
#      displacement  cylinders fuel_system fuel_tank_capacity fuel_type  \
# 687         72 cc        0.0         NaN           0 litres  Electric
# 688         72 cc        0.0         NaN           0 litres  Electric
# 689         72 cc        0.0         NaN           0 litres  Electric
# ...

# %%
new_df.loc[df['model'] == 'Range Sport', 'fuel_system'] = 'Injection'
new_df.loc[df['model'] == 'Outlander', 'fuel_system'] = 'Injection'
new_df.loc[df['model'] == 'F-Type', 'fuel_system'] = 'Injection'
new_df.loc[df['model'] == 'Outlander', 'fuel_system'] = 'Injection'
new_df.loc[df['model'] == 'E Verito', 'fuel_system'] = 'Injection'
new_df.loc[df['model'] == 'Kona Electric', 'fuel_system'] = 'Injection'

# %%
row_range = new_df[new_df['model'] == 'E2O Plus']
row_range
# Out:
#          make     model ex-showroom_price  body_type displacement  cylinders  \
# 615  Mahindra  E2O Plus      Rs. 8,81,425  Hatchback          NaN        0.0
# 616  Mahindra  E2O Plus      Rs. 9,57,177  Hatchback          NaN        0.0
#
#     fuel_system fuel_tank_capacity fuel_type city_mileage  seating_capacity  \
# 615   Injection           0 litres  Electric  80 km/litre               4.0
# 616   Injection           0 litres  Electric  80 km/litre               4.0
#
#         basic_warranty child_safety_locks  number_of_airbags  \
# 615  3 years 60000 kms                Yes                0.0
# 616  3 years 60000 kms                Yes                0.0
#
#            parking_assistance navigation_system
# 615              Rear sensors               Yes
# 616  Rear sensors with camera               Yes

# %%
new_df.isna().sum()
# Out:
# make                  75
# model                  0
# ex-showroom_price      0
# body_type              6
# displacement          12
# cylinders              0
# fuel_system            0
# fuel_tank_capacity     0
# fuel_type              0
# city_mileage           0
# seating_capacity       0
# basic_warranty         0
# child_safety_locks     0
# number_of_airbags      0
# parking_assistance     0
# navigation_system      0
# dtype: int64

# %%
new_df[new_df['displacement'].isna()]
# Out:
#           make                              model ex-showroom_price  \
# 615   Mahindra                           E2O Plus      Rs. 8,81,425
# 616   Mahindra                           E2O Plus      Rs. 9,57,177
# 617       Tata                           Tigor Ev      Rs. 9,60,868
# 618       Tata                           Tigor Ev      Rs. 9,75,868
# 619       Tata                           Tigor Ev      Rs. 9,44,175
# 745         Mg                              Zs Ev     Rs. 20,88,000
# 746         Mg                              Zs Ev     Rs. 23,58,000
# 862        NaN  Mercedes-Benz Amg Gt 4-Door Coupe   Rs. 2,42,00,000
# 1006      Tata                           Nexon Ev     Rs. 13,99,000
# 1007      Tata                           Nexon Ev     Rs. 14,99,000
# 1008      Tata                           Nexon Ev     Rs. 15,99,000
# 1205   Hyundai                      Kona Electric     Rs. 23,71,858
#
#       body_type displacement  cylinders fuel_system fuel_tank_capacity  \
# ...

# %% [markdown]
# We can see all are EV's so there will be no displacement or its equalent.

# %%
new_df.loc[df['model'] == 'Mercedes-Benz Amg Gt 4-Door Coupe', 'displacement'] = '3982 cc'

# %%
new_df.isna().sum()
# Out:
# make                  75
# model                  0
# ex-showroom_price      0
# body_type              6
# displacement          11
# cylinders              0
# fuel_system            0
# fuel_tank_capacity     0
# fuel_type              0
# city_mileage           0
# seating_capacity       0
# basic_warranty         0
# child_safety_locks     0
# number_of_airbags      0
# parking_assistance     0
# navigation_system      0
# dtype: int64

# %%
nan_counts3 = new_df.groupby('model')['make'].apply(lambda x: x.isna().sum())
nan_counts3_sorted = nan_counts3.sort_values(ascending=False)
nan_counts3_sorted
# Out:
# model
# Go+                        9
# Mercedes-Benz E-Class      8
# Mercedes-Benz C-Class      6
# Mercedes-Benz Gla-Class    6
# Mercedes-Benz Gls          5
#                           ..
# Grand I10                  0
# Grand I10 Nios             0
# Grand I10 Prime            0
# Granturismo                0
# Zs Ev                      0
# Name: make, Length: 263, dtype: int64

# %%
new_df['make'].value_counts()
# Out:
# Maruti Suzuki       149
# Hyundai             130
# Mahindra            119
# Tata                100
# Toyota               82
# Honda                64
# Skoda                43
# Ford                 43
# Bmw                  37
# Renault              36
# Volkswagen           34
# Audi                 31
# Nissan               29
# Jeep                 28
# Land Rover Rover     27
# Fiat                 23
# Jaguar               22
# Kia                  21
# Volvo                18
# Datsun               15
# Porsche              14
# Maruti Suzuki R      14
# Lamborghini          13
# Mg                   13
# Icml                 11
# Land Rover           10
# Lexus                10
# Mini                 10
# Maserati              9
# Ferrari               8
# Mitsubishi            7
# Bentley               6
# Premier               6
# Force                 6
# Isuzu                 5
# Aston Martin          3
# Bajaj                 2
# Bugatti               2
# ...

# %%
new_df[new_df['make'].isna()]
# Out:
#      make                    model ex-showroom_price body_type displacement  \
# 252   NaN    Mercedes-Benz B-Class     Rs. 29,88,311       MPV      1595 cc
# 253   NaN    Mercedes-Benz B-Class     Rs. 30,89,851       MPV      2143 cc
# 254   NaN    Mercedes-Benz B-Class     Rs. 31,98,662       MPV      1595 cc
# 255   NaN    Mercedes-Benz B-Class     Rs. 33,03,282       MPV      2143 cc
# 256   NaN  Mercedes-Benz Cla-Class     Rs. 35,99,000     Sedan      1991 cc
# ...   ...                      ...               ...       ...          ...
# 1151  NaN  Mercedes-Benz Gla-Class     Rs. 80,67,000       SUV      1991 cc
# 1219  NaN      Rolls-Royce Phantom   Rs. 9,50,00,000     Sedan      6749 cc
# 1220  NaN      Rolls-Royce Phantom   Rs. 7,54,00,000     Sedan      6749 cc
# 1251  NaN        Mercedes-Benz Glc     Rs. 52,75,000       SUV      1991 cc
# 1252  NaN        Mercedes-Benz Glc     Rs. 57,75,000       SUV      1950 cc
#
# ...

# %%
new_df.loc[df['model'] == 'Mercedes-Benz A-Class', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz B-Class', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz C-Class', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz C-Class Cabriolet', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz E-Class', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz E-Class All Terrain', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz V-Class', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz S-Class', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz S-Class Cabriolet', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz G-Class', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz Cla-Class', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz E-Class Cabriolet', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz Gls', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz Glc', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz Gle', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz Cls', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz Gla-Class', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz Amg Gt 4-Door Coupe', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz Amg-Gt', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Mercedes-Benz Maybach', 'make'] = 'Mercedes-Benz'
new_df.loc[df['model'] == 'Rolls-Royce Phantom', 'make'] = 'Rolls-Royce'
new_df.loc[df['model'] == 'Rolls-Royce Drophead Coupe', 'make'] = 'Rolls-Royce'
new_df.loc[df['model'] == 'Rolls-Royce Dawn', 'make'] = 'Rolls-Royce'
new_df.loc[df['model'] == 'Rolls-Royce Phantom Coupe', 'make'] = 'Rolls-Royce'
new_df.loc[df['model'] == 'Rolls-Royce Cullinan', 'make'] = 'Rolls-Royce'
new_df.loc[df['model'] == 'Rolls-Royce Wraith', 'make'] = 'Rolls-Royce'
new_df.loc[df['model'] == 'Rolls-Royce Ghost Series Ii', 'make'] = 'Rolls-Royce'
new_df.loc[df['model'] == 'Go+', 'make'] = 'Datsun'

# %%
new_df.loc[new_df['make'] == 'Maruti Suzuki R', 'make'] = 'Maruti Suzuki'

# %%
new_df.isna().sum()
# Out:
# make                   0
# model                  0
# ex-showroom_price      0
# body_type              6
# displacement          11
# cylinders              0
# fuel_system            0
# fuel_tank_capacity     0
# fuel_type              0
# city_mileage           0
# seating_capacity       0
# basic_warranty         0
# child_safety_locks     0
# number_of_airbags      0
# parking_assistance     0
# navigation_system      0
# dtype: int64

# %%
new_df['body_type'].value_counts()
# Out:
# SUV                    451
# Sedan                  333
# Hatchback              312
# Coupe                   41
# MUV                     39
# MPV                     39
# Convertible             20
# Crossover               18
# Sports                   3
# Pick-up                  3
# Sports, Convertible      2
# Sedan, Coupe             2
# Crossover, SUV           2
# SUV, Crossover           2
# Sports, Hatchback        1
# Sedan, Crossover         1
# Coupe, Convertible       1
# Name: body_type, dtype: int64

# %%
new_df[new_df['body_type'].isna()]
# Out:
#           make          model ex-showroom_price body_type displacement  \
# 239   Mahindra     Alturas G4     Rs. 27,70,150       NaN      2157 cc
# 843   Maserati         Ghibli   Rs. 1,33,87,856       NaN      2987 cc
# 844   Maserati         Ghibli   Rs. 1,38,81,858       NaN      2987 cc
# 845   Maserati         Ghibli   Rs. 1,42,47,814       NaN      2987 cc
# 1253   Porsche  Cayenne Coupe   Rs. 1,31,51,000       NaN      2995 cc
# 1254   Porsche  Cayenne Coupe   Rs. 1,97,63,000       NaN      2995 cc
#
#       cylinders fuel_system fuel_tank_capacity fuel_type city_mileage  \
# 239         4.0   Injection          70 litres    Diesel   8 km/litre
# 843         0.0   Injection          70 litres    Diesel   8 km/litre
# 844         0.0   Injection          70 litres    Diesel   8 km/litre
# 845         0.0   Injection          70 litres    Diesel   8 km/litre
# 1253        6.0   Injection          75 litres    Petrol   9 km/litre
# ...

# %%
new_df.loc[df['model'] == 'Alturas G4', 'body_type'] = 'SUV'
new_df.loc[df['model'] == 'Ghibli', 'body_type'] = 'Sedan'
new_df.loc[df['model'] == 'Cayenne Coupe', 'body_type'] = 'Coupe'

# %%
new_df.isna().sum()
# Out:
# make                   0
# model                  0
# ex-showroom_price      0
# body_type              0
# displacement          11
# cylinders              0
# fuel_system            0
# fuel_tank_capacity     0
# fuel_type              0
# city_mileage           0
# seating_capacity       0
# basic_warranty         0
# child_safety_locks     0
# number_of_airbags      0
# parking_assistance     0
# navigation_system      0
# dtype: int64

# %%
new_df.loc[df['fuel_type'] == 'Electric', 'fuel_tank_capacity'] = 0

# %%
new_df.head()
# Out:
#    make      model ex-showroom_price  body_type displacement  cylinders  \
# 0  Tata  Nano Genx      Rs. 2,92,667  Hatchback       624 cc        2.0
# 1  Tata  Nano Genx      Rs. 2,36,447  Hatchback       624 cc        2.0
# 2  Tata  Nano Genx      Rs. 2,96,661  Hatchback       624 cc        2.0
# 3  Tata  Nano Genx      Rs. 3,34,768  Hatchback       624 cc        2.0
# 4  Tata  Nano Genx      Rs. 2,72,223  Hatchback       624 cc        2.0
#
#   fuel_system fuel_tank_capacity fuel_type city_mileage  seating_capacity  \
# 0   Injection          24 litres    Petrol  16 km/litre               4.0
# 1   Injection          24 litres    Petrol  16 km/litre               4.0
# 2   Injection          15 litres       CNG  16 km/litre               4.0
# 3   Injection          24 litres    Petrol  16 km/litre               4.0
# 4   Injection          24 litres    Petrol  16 km/litre               4.0
#
#                                       basic_warranty child_safety_locks  \
# ...

# %%
new_df.tail()
# Out:
#             make    model ex-showroom_price body_type displacement  cylinders  \
# 1271       Honda     City     Rs. 13,02,000     Sedan      1498 cc        4.0
# 1272       Honda     City     Rs. 14,21,000     Sedan      1498 cc        4.0
# 1273       Honda     City     Rs. 14,31,000     Sedan      1497 cc        4.0
# 1274       Honda     City     Rs. 12,01,000     Sedan      1497 cc        4.0
# 1275  Mitsubishi  Montero     Rs. 68,62,560       SUV      3200 cc        4.0
#
#      fuel_system fuel_tank_capacity fuel_type   city_mileage  \
# 1271   Injection          40 litres    Diesel  22.6 km/litre
# 1272   Injection          40 litres    Diesel  22.6 km/litre
# 1273   Injection          40 litres    Petrol    18 km/litre
# 1274   Injection          40 litres    Petrol  14.3 km/litre
# 1275   Injection          88 litres    Diesel  8.25 km/litre
#
#       seating_capacity                                  basic_warranty  \
# ...

# %%
new_df.isna().sum()
# Out:
# make                   0
# model                  0
# ex-showroom_price      0
# body_type              0
# displacement          11
# cylinders              0
# fuel_system            0
# fuel_tank_capacity     0
# fuel_type              0
# city_mileage           0
# seating_capacity       0
# basic_warranty         0
# child_safety_locks     0
# number_of_airbags      0
# parking_assistance     0
# navigation_system      0
# dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1276 entries, 0 to 1275
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   make                1276 non-null   object
#  1   model               1276 non-null   object
#  2   ex-showroom_price   1276 non-null   object
#  3   body_type           1276 non-null   object
#  4   displacement        1265 non-null   object
#  5   cylinders           1276 non-null   float64
#  6   fuel_system         1276 non-null   object
#  7   fuel_tank_capacity  1276 non-null   object
#  8   fuel_type           1276 non-null   object
#  9   city_mileage        1276 non-null   object
#  10  seating_capacity    1276 non-null   float64
#  11  basic_warranty      1276 non-null   object
#  12  child_safety_locks  1276 non-null   object
#  13  number_of_airbags   1276 non-null   float64
#  14  parking_assistance  1276 non-null   object
# ...

# %% [markdown]
# We can observe that there are very minimum null values

# %% [markdown]
# We have complted the data cleaning part.

# %% [markdown]
# # Analysing the Data

# %% [markdown]
# # Basic Umbrella analysis

# %% [markdown]
# Average Number of Airbags a car is having.

# %%
avg_airbags=new_df['number_of_airbags'].mean()
avg_airbags.round()
# Out:
# 3.0

# %%
new_df['body_type'].value_counts()
# Out:
# SUV                    452
# Sedan                  336
# Hatchback              312
# Coupe                   43
# MUV                     39
# MPV                     39
# Convertible             20
# Crossover               18
# Sports                   3
# Pick-up                  3
# Sports, Convertible      2
# Sedan, Coupe             2
# Crossover, SUV           2
# SUV, Crossover           2
# Sports, Hatchback        1
# Sedan, Crossover         1
# Coupe, Convertible       1
# Name: body_type, dtype: int64

# %%
plt.figure(figsize=(30, 6))
plt.bar(new_df['body_type'], new_df.index)
# Out:
# <BarContainer object of 1276 artists>

# %%
new_df['make'].value_counts()
# Out:
# Maruti Suzuki       163
# Hyundai             130
# Mahindra            119
# Tata                100
# Toyota               82
# Honda                64
# Mercedes-Benz        57
# Ford                 43
# Skoda                43
# Bmw                  37
# Renault              36
# Volkswagen           34
# Audi                 31
# Nissan               29
# Jeep                 28
# Land Rover Rover     27
# Datsun               24
# Fiat                 23
# Jaguar               22
# Kia                  21
# Volvo                18
# Porsche              14
# Lamborghini          13
# Mg                   13
# Icml                 11
# Mini                 10
# Land Rover           10
# Lexus                10
# Rolls-Royce           9
# Maserati              9
# Ferrari               8
# Mitsubishi            7
# Force                 6
# Bentley               6
# Premier               6
# Isuzu                 5
# Aston Martin          3
# Bugatti               2
# ...

# %%
plt.figure(figsize=(40, 6))
plt.bar(new_df['make'], new_df.index)
# Out:
# <BarContainer object of 1276 artists>

# %%
new_df['ex-showroom_price'] = new_df['ex-showroom_price'].str.replace('Rs. ', '').str.replace(',', '')
new_df
# Out:
# <ipython-input-209-a6bc179fddc3>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   new_df['ex-showroom_price'] = new_df['ex-showroom_price'].str.replace('Rs. ', '').str.replace(',', '')
# <ipython-input-209-a6bc179fddc3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['ex-showroom_price'] = new_df['ex-showroom_price'].str.replace('Rs. ', '').str.replace(',', '')
#             make      model ex-showroom_price  body_type displacement  \
# 0           Tata  Nano Genx            292667  Hatchback       624 cc
# 1           Tata  Nano Genx            236447  Hatchback       624 cc
# 2           Tata  Nano Genx            296661  Hatchback       624 cc
# ...

# %%
new_df['ex-showroom_price'] = new_df['ex-showroom_price'].astype(float)
# Out:
# <ipython-input-212-a600c4f2607e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['ex-showroom_price'] = new_df['ex-showroom_price'].astype(float)

# %%
correlation_matrix = new_df.corr()
correlation_matrix
# Out:
# <ipython-input-213-fa3d14a4d996>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = new_df.corr()
#                    ex-showroom_price  cylinders  seating_capacity  \
# ex-showroom_price           1.000000   0.718095          -0.31116
# cylinders                   0.718095   1.000000          -0.24608
# seating_capacity           -0.311160  -0.246080           1.00000
# number_of_airbags           0.323961   0.412401          -0.07098
#
#                    number_of_airbags
# ex-showroom_price           0.323961
# cylinders                   0.412401
# seating_capacity           -0.070980
# number_of_airbags           1.000000

# %%
import seaborn as sns

plt.figure(figsize=(40, 6))
sns.violinplot(x='make', y='ex-showroom_price', data=new_df)

# Adding labels and title
plt.xlabel('make')
plt.ylabel('ex-showroom_price')
plt.title('Violin Plot')

# Show plot
plt.show()

# %% [markdown]
# # Safety

# %%
subtable_1 = new_df[(new_df['ex-showroom_price'] >= 200000) & (new_df['ex-showroom_price'] < 300000)]

# %%
a_ = plt.scatter(subtable_1['number_of_airbags'], subtable_1['ex-showroom_price'], c=subtable_1['ex-showroom_price'])

# %%
subtable_2 = new_df[(new_df['ex-showroom_price'] >= 200000) & (new_df['ex-showroom_price'] < 500000)]

# %%
b_ = plt.scatter(subtable_2['number_of_airbags'], subtable_2['ex-showroom_price'], c=subtable_2['ex-showroom_price'])

# %% [markdown]
# We can observe that most cars in this range have no airbags at all.

# %% [markdown]
# From both the above plots we can conclude that under the 5 lakh range cars only offer 2 airbags.

# %%
subtable_3 = new_df[(new_df['ex-showroom_price'] >= 500000) & (new_df['ex-showroom_price'] < 1000000)]

# %%
c_ = plt.scatter(subtable_3['number_of_airbags'], subtable_3['ex-showroom_price'], c=subtable_3['ex-showroom_price'])

# %% [markdown]
# We can see that most cars in the range have 0 or 2 airbags where as few companies seem to be offering 6 airbags. Let's check the 7 Lakh to 10 Lakh range for a more detailed idea.

# %% [markdown]
# Let's take 3 major selling brands and observe what are the top selling models

# %%
subtable_4 = new_df[(new_df['ex-showroom_price'] >= 700000) & (new_df['ex-showroom_price'] < 1000000)]

# %%
d_ = plt.scatter(subtable_4['number_of_airbags'], subtable_4['ex-showroom_price'], c=subtable_4['ex-showroom_price'])

# %% [markdown]
# Seems to be very similar.

# %%
subtable_5 = new_df[(new_df['ex-showroom_price'] >= 1000000) & (new_df['ex-showroom_price'] < 2000000)]
d_ = plt.scatter(subtable_5['number_of_airbags'], subtable_5['ex-showroom_price'], c=subtable_5['ex-showroom_price'])

# %% [markdown]
# As we move higher up the rice range we can see that more cars are offering 6 airbags.

# %%
subtable_6 = new_df[(new_df['ex-showroom_price'] >= 2000000) & (new_df['ex-showroom_price'] < 3000000)]
d_ = plt.scatter(subtable_6['number_of_airbags'], subtable_6['ex-showroom_price'], c=subtable_6['ex-showroom_price'])

# %% [markdown]
# It is at 20 Lakhs to 30 Lakhs that we can observe we have a lot of cars offering 6 or more airbags.

# %% [markdown]
# **SO the most ideal price point at which we can balace both safety and value for money is from 10-20 Lakh range**

# %% [markdown]
# Now lets check manufacturer and airbag relationship

# %%
plt.figure(figsize=(10, 6))  # Adjust width and height as needed

b1_ = plt.scatter(subtable_2['make'], subtable_2['number_of_airbags'], c=subtable_2['number_of_airbags'])

# Adding labels and title
plt.xlabel('Maker')
plt.ylabel('Number of Airbags')
plt.title('Scatter Plot of Number of Airbags by Maker')

# Show plot
plt.show()

# %% [markdown]
# We can see that only
# * Tata
# * Datsun
# * Renault
# * Maruthi Suzuki
#
# are offering 2 airbags in 2-5 Lakh range.

# %%
plt.figure(figsize=(20, 6))  # Adjust width and height as needed

b1_ = plt.scatter(subtable_3['make'], subtable_3['number_of_airbags'], c=subtable_3['number_of_airbags'])

# Adding labels and title
plt.xlabel('Maker')
plt.ylabel('Number of Airbags')
plt.title('Scatter Plot of Number of Airbags by Maker')

# Show plot
plt.show()

# %% [markdown]
# Makers offering more than 2 airbags in the 5-10 Lakh range are:
# * Hyundai
# * Renault
# * Toyota
# * Ford
#
# where as majority offer 2 airbags.

# %%
plt.figure(figsize=(20, 6))  # Adjust width and height as needed

b1_ = plt.scatter(subtable_5['make'], subtable_5['number_of_airbags'], c=subtable_5['number_of_airbags'])

# Adding labels and title
plt.xlabel('Maker')
plt.ylabel('Number of Airbags')
plt.title('Scatter Plot of Number of Airbags by Maker')

# Show plot
plt.show()

# %% [markdown]
# We can see that majority makers offer 6 airbags option at 10-20 Lakh price range

# %%
plt.figure(figsize=(20, 6))  # Adjust width and height as needed

b1_ = plt.scatter(subtable_6['make'], subtable_6['number_of_airbags'], c=subtable_6['number_of_airbags'])

# Adding labels and title
plt.xlabel('Maker')
plt.ylabel('Number of Airbags')
plt.title('Scatter Plot of Number of Airbags by Maker')

# Show plot
plt.show()

# %% [markdown]
# We can see that most makers offer 6 or more airbags in 20-30 Lakh range.

# %%
new_df['child_safety_locks'].value_counts()
# Out:
# Yes    1201
# No       75
# Name: child_safety_locks, dtype: int64

# %% [markdown]
# **We can see that most cars have child safety locks so no need of further analysis. So according to the data the best range to buy a car that is safe and has good features is 10-20 Lakh range**

# %% [markdown]
# # Maruthi Suzuki

# %%
maker_name = 'Maruti Suzuki'
ms_subtable = new_df[new_df['make'] == maker_name]
ms_subtable
# Out:
#                make  model ex-showroom_price  body_type displacement  \
# 24    Maruti Suzuki   Eeco      Rs. 3,52,136        MPV      1196 cc
# 25    Maruti Suzuki   Eeco      Rs. 3,80,573        MPV      1196 cc
# 26    Maruti Suzuki   Eeco      Rs. 3,92,967        MPV      1196 cc
# 27    Maruti Suzuki   Eeco      Rs. 4,66,057        MPV      1196 cc
# 28    Maruti Suzuki   Eeco      Rs. 4,25,255        MPV      1196 cc
# ...             ...    ...               ...        ...          ...
# 1182  Maruti Suzuki  Wagon      Rs. 5,20,500  Hatchback      1197 cc
# 1183  Maruti Suzuki  Wagon      Rs. 5,67,500  Hatchback      1197 cc
# 1184  Maruti Suzuki  Wagon      Rs. 5,33,000  Hatchback       998 cc
# 1185  Maruti Suzuki  Wagon      Rs. 5,00,500  Hatchback       998 cc
# 1186  Maruti Suzuki  Wagon      Rs. 5,07,500  Hatchback       998 cc
#
#       cylinders fuel_system fuel_tank_capacity fuel_type city_mileage  \
# ...

# %%
ms_subtable['body_type'].value_counts()
# Out:
# Hatchback    96
# Sedan        31
# MPV          17
# SUV          11
# MUV           4
# Crossover     4
# Name: body_type, dtype: int64

# %%
plt.bar(ms_subtable['body_type'], ms_subtable.index)
# Out:
# <BarContainer object of 163 artists>

# %%
ft_ms = ms_subtable['fuel_type'].value_counts()
ft_ms
# Out:
# Petrol          110
# Diesel           42
# CNG               8
# CNG + Petrol      3
# Name: fuel_type, dtype: int64

# %%
plt.pie(ft_ms,labels=ft_ms.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca2c1a2da0>,
# ...
#  [Text(-0.16311445481912906, -1.0878389929714132, 'Petrol'),
#   Text(0.3883704294013894, 1.0291590788437814, 'Diesel'),
#   Text(-0.6236777370088574, 0.9061048947884073, 'CNG'),
#   Text(-0.8003804494463364, 0.7545801058496578, 'CNG + Petrol')],
#  [Text(-0.08897152081043402, -0.5933667234389526, '67.5%'),
#   Text(0.21183841603712145, 0.5613594975511534, '25.8%'),
#   Text(-0.3401878565502858, 0.4942390335209494, '4.9%'),
#   Text(-0.43657115424345616, 0.41158914864526785, '1.8%')])

# %% [markdown]
# Major sales in petrol followed by diesel

# %%
exp_ms = ms_subtable['ex-showroom_price'].value_counts()
exp_ms
# Out:
# Rs. 9,97,689    2
# Rs. 9,80,689    2
# Rs. 3,52,136    1
# Rs. 7,58,212    1
# Rs. 2,82,778    1
#                ..
# Rs. 4,09,000    1
# Rs. 4,15,000    1
# Rs. 4,32,500    1
# Rs. 4,38,500    1
# Rs. 5,07,500    1
# Name: ex-showroom_price, Length: 161, dtype: int64

# %%
ms_subtable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163 entries, 24 to 1186
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   make                163 non-null    object
#  1   model               163 non-null    object
#  2   ex-showroom_price   163 non-null    object
#  3   body_type           163 non-null    object
#  4   displacement        163 non-null    object
#  5   cylinders           163 non-null    float64
#  6   fuel_system         163 non-null    object
#  7   fuel_tank_capacity  163 non-null    object
#  8   fuel_type           163 non-null    object
#  9   city_mileage        163 non-null    object
#  10  seating_capacity    163 non-null    float64
#  11  basic_warranty      163 non-null    object
#  12  child_safety_locks  163 non-null    object
#  13  number_of_airbags   163 non-null    float64
#  14  parking_assistance  163 non-null    object
# ...

# %%
ms_subtable['ex-showroom_price'] = ms_subtable['ex-showroom_price'].str.replace('Rs. ', '').str.replace(',', '')
ms_subtable
# Out:
# <ipython-input-116-0f3fb69d2717>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   ms_subtable['ex-showroom_price'] = ms_subtable['ex-showroom_price'].str.replace('Rs. ', '').str.replace(',', '')
# <ipython-input-116-0f3fb69d2717>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ms_subtable['ex-showroom_price'] = ms_subtable['ex-showroom_price'].str.replace('Rs. ', '').str.replace(',', '')
#                make  model ex-showroom_price  body_type displacement  \
# 24    Maruti Suzuki   Eeco            352136        MPV      1196 cc
# 25    Maruti Suzuki   Eeco            380573        MPV      1196 cc
# 26    Maruti Suzuki   Eeco            392967        MPV      1196 cc
# ...

# %%
ms_subtable['ex-showroom_price'] = ms_subtable['ex-showroom_price'].astype(float)
# Out:
# <ipython-input-118-1e0aa52116e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ms_subtable['ex-showroom_price'] = ms_subtable['ex-showroom_price'].astype(float)

# %%
exp_ms = ms_subtable['ex-showroom_price'].value_counts()
exp_ms
# Out:
# 997689.0    2
# 980689.0    2
# 352136.0    1
# 758212.0    1
# 282778.0    1
#            ..
# 409000.0    1
# 415000.0    1
# 432500.0    1
# 438500.0    1
# 507500.0    1
# Name: ex-showroom_price, Length: 161, dtype: int64

# %%
plt.figure(figsize=(30, 10))
plt.scatter(ms_subtable['model'], ms_subtable['ex-showroom_price'], color='red', marker='o')
# Adding title and labels
plt.title('Model vs Price')
plt.xlabel('Model')
plt.ylabel('Price')

# Show plot
plt.show()

# %% [markdown]
# The Sales seems to be scattered throughout the price range.

# %%
csl_ms = ms_subtable['child_safety_locks'].value_counts()
csl_ms
plt.pie(csl_ms,labels=csl_ms.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca299c2a40>,
# ...
#  [Text(0.8147743395103825, -0.7390147330570753, 'Yes'),
#   Text(-0.8147743957285161, 0.7390146710757722, 'No')],
#  [Text(0.4444223670056631, -0.4030989453038592, '98.8%'),
#   Text(-0.4444223976700996, 0.40309891149587573, '1.2%')])

# %% [markdown]
# Majority of the cars have child safety locks.

# %%
noa_ms = ms_subtable['number_of_airbags'].value_counts()
plt.pie(noa_ms,labels=noa_ms.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca297920e0>,
# ...
#  [Text(-0.015311196266311158, -1.0998934345057683, '2.0'),
#   Text(0.34842053768333436, 1.0433614565051061, '1.0'),
#   Text(-0.5882954203102508, 0.9294667817851187, '0.0')],
#  [Text(-0.008351561599806085, -0.5999418733667826, '71.8%'),
#   Text(0.19004756600909145, 0.5691062490027851, '18.4%'),
#   Text(-0.3208884110783186, 0.506981880973701, '9.8%')])

# %% [markdown]
# Most cars have 2 Airbags where 10 percent cars have no airbags at all.

# %%
ns_ms = ms_subtable['navigation_system'].value_counts()
plt.pie(ns_ms,labels=ns_ms.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca2964b7f0>,
# ...
#  [Text(0.3795406136180822, -1.032448024170907, 'No'),
#   Text(-0.3795406136180821, 1.032448024170907, 'Yes')],
#  [Text(0.20702215288259027, -0.5631534677295856, '83.4%'),
#   Text(-0.2070221528825902, 0.5631534677295856, '16.6%')])

# %%
mo_ms = ms_subtable['model'].value_counts()
plt.pie(mo_ms, labels=mo_ms.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca1e42b550>,
# ...
#  [Text(-1.0006396706871992, 0.45685911334569446, 'Wagon'),
#   Text(-1.0931866603134988, -0.12224126027090564, 'Ciaz'),
#   Text(-0.8750136928155793, -0.6665966076910707, 'Dzire'),
#   Text(-0.40813277178592533, -1.0214830593770696, 'Swift'),
#   Text(0.1537901863197674, -1.0891962993839686, 'Baleno'),
#   Text(0.623677630964275, -0.9061049677795558, 'Celerio'),
#   Text(0.930096268916961, -0.5872996939780817, 'Ertiga'),
#   Text(1.0826693524148083, -0.19449183361185093, 'S-Presso'),
#   Text(1.0805248059884924, 0.20607315119522687, 'Vitara Brezza'),
#   Text(0.9567235576014379, 0.5428443923726655, 'Celerio X'),
#   Text(0.7468321824749378, 0.8076148161219688, 'Alto'),
#   Text(0.4855930523305501, 0.9870153937646058, 'Ignis'),
#   Text(0.22570656383761475, 1.0765948852937288, 'Alto K10'),
#   Text(-0.005889100023382878, 1.0999842355692715, 'Eeco'),
#   Text(-0.19565095145559902, 1.0824604866666123, 'Xl6'),
# ...

# %% [markdown]
# Highest selling cars
# 1. Ciaz
# 2. Dzire
# 3. Swift

# %% [markdown]
# Most cars don't have a navigation system.

# %% [markdown]
# # Hyndai

# %%
maker_name_1 = 'Hyundai'
h_subtable = new_df[new_df['make'] == maker_name_1]
h_subtable
# Out:
#          make          model ex-showroom_price  body_type displacement  \
# 46    Hyundai         Santro      Rs. 4,29,990  Hatchback      1086 cc
# 47    Hyundai         Santro      Rs. 5,03,990  Hatchback      1086 cc
# 48    Hyundai         Santro      Rs. 5,47,990  Hatchback      1086 cc
# 49    Hyundai         Santro      Rs. 5,30,990  Hatchback      1086 cc
# 50    Hyundai         Santro      Rs. 5,12,990  Hatchback      1086 cc
# ...       ...            ...               ...        ...          ...
# 1132  Hyundai          Creta     Rs. 11,07,167        SUV      1396 cc
# 1133  Hyundai          Creta     Rs. 10,92,192        SUV      1591 cc
# 1134  Hyundai          Creta     Rs. 12,79,983        SUV      1591 cc
# 1135  Hyundai          Creta     Rs. 14,14,247        SUV      1582 cc
# 1205  Hyundai  Kona Electric     Rs. 23,71,858        SUV          NaN
#
#       cylinders fuel_system fuel_tank_capacity fuel_type city_mileage  \
# ...

# %%
h_subtable['ex-showroom_price'] = h_subtable['ex-showroom_price'].str.replace('Rs. ', '').str.replace(',', '')
h_subtable
# Out:
# <ipython-input-156-6128d4834665>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   h_subtable['ex-showroom_price'] = h_subtable['ex-showroom_price'].str.replace('Rs. ', '').str.replace(',', '')
# <ipython-input-156-6128d4834665>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_subtable['ex-showroom_price'] = h_subtable['ex-showroom_price'].str.replace('Rs. ', '').str.replace(',', '')
#          make          model ex-showroom_price  body_type displacement  \
# 46    Hyundai         Santro            429990  Hatchback      1086 cc
# 47    Hyundai         Santro            503990  Hatchback      1086 cc
# 48    Hyundai         Santro            547990  Hatchback      1086 cc
# ...

# %%
h_subtable['ex-showroom_price'] = h_subtable['ex-showroom_price'].astype(float)
# Out:
# <ipython-input-157-9a0ecfb14cf3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_subtable['ex-showroom_price'] = h_subtable['ex-showroom_price'].astype(float)

# %%
exp_h = h_subtable['ex-showroom_price'].value_counts()
exp_h
# Out:
# 536859.0     2
# 999990.0     2
# 999900.0     2
# 556130.0     2
# 2246749.0    1
#             ..
# 460369.0     1
# 568930.0     1
# 551530.0     1
# 903800.0     1
# 2371858.0    1
# Name: ex-showroom_price, Length: 126, dtype: int64

# %%
plt.figure(figsize=(30, 10))
plt.scatter(h_subtable['model'], h_subtable['ex-showroom_price'], color='red', marker='o')

# Adding title and labels
plt.title('Model vs Price')
plt.xlabel('Model')
plt.ylabel('Price')

# Show plot
plt.show()

# %% [markdown]
# We can observe that Hyundai sells majority of its car's in the lower price range.

# %%
bt_h = h_subtable['body_type'].value_counts()
plt.pie(bt_h, labels=bt_h.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca1f92bfa0>,
# ...
#  [Text(-1.0072881918324172, -0.44200735129065394, 'Hatchback'),
#   Text(0.9359698635933222, -0.5778930821917648, 'Sedan'),
#   Text(0.10322492271009896, 1.095145933349293, 'SUV')],
#  [Text(-0.5494299228176821, -0.24109491888581122, '35.4%'),
#   Text(0.5105290165054485, -0.3152144084682353, '33.8%'),
#   Text(0.05630450329641761, 0.5973523272814325, '30.8%')])

# %% [markdown]
# we can see that Hundai has equally good shares in all three segments

# %%
ft_h = h_subtable['fuel_type'].value_counts()
plt.pie(ft_h, labels=ft_h.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca2105f340>,
# ...
#  [Text(-0.4848612429303704, -0.9873750934189177, 'Petrol'),
#   Text(0.6864983654292205, 0.8594882164771129, 'Diesel'),
#   Text(-0.5829112190420215, 0.9328528880348416, 'CNG'),
#   Text(-0.7512776245577857, 0.8034811328455765, 'CNG + Petrol'),
#   Text(-0.8253175018189891, 0.7272214388968901, 'Electric')],
#  [Text(-0.2644697688711111, -0.538568232773955, '57.7%'),
#   Text(0.3744536538704839, 0.4688117544420615, '35.4%'),
#   Text(-0.31795157402292074, 0.5088288480190044, '3.8%'),
#   Text(-0.4097877952133376, 0.43826243609758714, '2.3%'),
#   Text(-0.4501731828103576, 0.39666623939830364, '0.8%')])

# %% [markdown]
# More than 50% petrol vehicles followed by diesel

# %%
csl_h = h_subtable['child_safety_locks'].value_counts()
plt.pie(csl_h, labels=csl_h.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca210bee90>,
# ...
#  [Text(0.8253174071349626, -0.7272215463529821, 'Yes'),
#   Text(-0.8253173401114294, 0.7272216224174001, 'No')],
#  [Text(0.450173131164525, -0.39666629801071746, '99.2%'),
#   Text(-0.45017309460623417, 0.3966663395004, '0.8%')])

# %% [markdown]
# Almost all the cars have child safety locks.

# %%
na_h = h_subtable['number_of_airbags'].value_counts()
plt.pie(na_h, labels=na_h.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca2111dae0>,
# ...
#  [Text(-0.2084399539663067, -1.0800707317534923, '2.0'),
#   Text(0.6224380563303182, 0.9069569262273351, '6.0'),
#   Text(-0.3173695761865097, 1.0532219861506857, '1.0'),
#   Text(-0.7115815192910487, 0.8388395206494763, '0.0')],
#  [Text(-0.11369452034525819, -0.5891294900473594, '66.2%'),
#   Text(0.33951166708926445, 0.49470377794218273, '20.8%'),
#   Text(-0.17311067791991436, 0.5744847197185559, '7.7%'),
#   Text(-0.3881353741587538, 0.45754882944516884, '5.4%')])

# %% [markdown]
# * Most cars have only 2.
# * But 20 percent cars have 6 airbags.

# %%
ns_h = h_subtable['navigation_system'].value_counts()
plt.pie(ns_h, labels=ns_h.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca20f8c310>,
# ...
#  [Text(-0.508578257758516, -0.9753707785941266, 'No'),
#   Text(0.508578166437711, 0.9753708262106552, 'Yes')],
#  [Text(-0.277406322413736, -0.5320204246877054, '56.9%'),
#   Text(0.27740627260238776, 0.5320204506603573, '43.1%')])

# %% [markdown]
# Eventhough more than 50 percent don't have a navigation system 43% is a healthy number given the price range at which majority of their cars sell.

# %%
mo_h = h_subtable['model'].value_counts()
plt.pie(mo_h, labels=mo_h.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca1e6dd720>,
# ...
#  [Text(-1.0621352290491421, 0.28612716615645994, 'Creta'),
#   Text(-0.9726254725678984, -0.5138090015872361, 'Venue'),
#   Text(-0.4848611735968239, -0.9873751274659043, 'Verna'),
#   Text(0.16186009039815663, -1.0880263375195938, 'Elite I20'),
#   Text(0.7316431835025368, -0.8214001777661565, 'Aura'),
#   Text(1.0470711503000627, -0.3371083004159101, 'Grand I10 Nios'),
#   Text(1.088026329942375, 0.1618601413323447, 'Xcent'),
#   Text(0.9328528334587498, 0.5829113063820105, 'Santro'),
#   Text(0.6441717984383826, 0.8916516663454737, 'Tucson'),
#   Text(0.311708673500321, 1.0549112298504886, 'Xcent Prime'),
#   Text(-0.0029537777250599807, 1.0999960341733743, 'Grand I10 Prime'),
#   Text(-0.3173695638602885, 1.0532219898649717, 'Grand I10'),
#   Text(-0.5601999042598709, 0.9466657632275669, 'I20 Active'),
#   Text(-0.7316432363747469, 0.8214001306714568, 'Elantra'),
# ...

# %% [markdown]
# Highest selling models :
# 1. Creta
# 2. Venue
# 3. Verna

# %% [markdown]
# # Mahindra

# %%
maker_name_1 = 'Mahindra'
m_subtable = new_df[new_df['make'] == maker_name_1]
m_subtable
# Out:
#           make        model ex-showroom_price  body_type displacement  \
# 212   Mahindra  Verito Vibe      Rs. 6,57,628  Hatchback      1461 cc
# 213   Mahindra  Verito Vibe      Rs. 6,85,729  Hatchback      1461 cc
# 214   Mahindra  Verito Vibe      Rs. 7,50,428  Hatchback      1461 cc
# 239   Mahindra   Alturas G4     Rs. 27,70,150        SUV      2157 cc
# 240   Mahindra   Alturas G4     Rs. 30,70,150        SUV      2157 cc
# ...        ...          ...               ...        ...          ...
# 1194  Mahindra    Nuvosport      Rs. 9,72,359        SUV      1493 cc
# 1195  Mahindra    Nuvosport     Rs. 10,48,603        SUV      1493 cc
# 1255  Mahindra       Verito      Rs. 7,48,370      Sedan      1461 cc
# 1256  Mahindra       Verito      Rs. 7,72,617      Sedan      1461 cc
# 1257  Mahindra       Verito      Rs. 8,45,154      Sedan      1461 cc
#
#       cylinders fuel_system fuel_tank_capacity fuel_type   city_mileage  \
# ...

# %%
m_subtable['ex-showroom_price'] = m_subtable['ex-showroom_price'].str.replace('Rs. ', '').str.replace(',', '')
m_subtable
# Out:
# <ipython-input-193-794d83ed3d48>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   m_subtable['ex-showroom_price'] = m_subtable['ex-showroom_price'].str.replace('Rs. ', '').str.replace(',', '')
# <ipython-input-193-794d83ed3d48>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_subtable['ex-showroom_price'] = m_subtable['ex-showroom_price'].str.replace('Rs. ', '').str.replace(',', '')
#           make        model ex-showroom_price  body_type displacement  \
# 212   Mahindra  Verito Vibe            657628  Hatchback      1461 cc
# 213   Mahindra  Verito Vibe            685729  Hatchback      1461 cc
# 214   Mahindra  Verito Vibe            750428  Hatchback      1461 cc
# ...

# %%
exp_m = m_subtable['ex-showroom_price'].value_counts()
exp_m_sorted = exp_m.sort_values(ascending=False)
exp_m_sorted
# Out:
# 1610180    2
# 1862586    2
# 1741319    2
# 1837586    2
# 1716319    2
#           ..
# 773678     1
# 797802     1
# 905642     1
# 984818     1
# 845154     1
# Name: ex-showroom_price, Length: 109, dtype: int64

# %%
m_subtable['ex-showroom_price'] = m_subtable['ex-showroom_price'].astype(float)
# Out:
# <ipython-input-195-77e51dbf7271>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_subtable['ex-showroom_price'] = m_subtable['ex-showroom_price'].astype(float)

# %%
avg_price_m = m_subtable['ex-showroom_price'].mean()
print("Average value of the Mahindra car:", avg_price_m)
# Out:
# Average value of the Mahindra car: 1105725.4201680673

# %%
plt.figure(figsize=(30, 10))
plt.scatter(m_subtable['model'], m_subtable['ex-showroom_price'], color='red', marker='o')

# Adding title and labels
plt.title('Model vs Price')
plt.xlabel('Model')
plt.ylabel('Price')

# Show plot
plt.show()

# %% [markdown]
# We can see that most mahindra cars are sold at lower prices

# %%
bt_m = m_subtable['body_type'].value_counts()
plt.pie(bt_m, labels=bt_m.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca1e624fa0>,
# ...
#  [Text(-0.22901839553117473, -1.0758952432780464, 'SUV'),
#   Text(0.6022114208091986, 0.9205114907739971, 'Hatchback'),
#   Text(-0.3716705826245287, 1.0353071901670265, 'MPV'),
#   Text(-0.7205686020467695, 0.831132293768185, 'Sedan')],
#  [Text(-0.1249191248351862, -0.5868519508789343, '65.5%'),
#   Text(0.3284789568050174, 0.5020971767858166, '22.7%'),
#   Text(-0.20272940870428835, 0.564713012818378, '6.7%'),
#   Text(-0.39303741929823793, 0.45334488750991897, '5.0%')])

# %% [markdown]
# Majority of it's sales come from SUV

# %%
ft_m = m_subtable['fuel_type'].value_counts()
plt.pie(ft_m, labels=ft_m.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca1e48c940>,
# ...
#  [Text(0.3165138100121571, -1.053479476815561, 'Diesel'),
#   Text(-0.17510492338331016, 1.0859734185544898, 'Petrol'),
#   Text(-0.7422567673591265, 0.811821957888292, 'Electric')],
#  [Text(0.1726438963702675, -0.5746251691721241, '81.5%'),
#   Text(-0.09551177639089643, 0.592349137393358, '14.3%'),
#   Text(-0.4048673276504326, 0.44281197702997743, '4.2%')])

# %% [markdown]
# Majority of Mahindra cars are diesel cars

# %%
csl_m = m_subtable['child_safety_locks'].value_counts()
plt.pie(csl_h, labels=csl_m.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca1e4c70a0>,
# ...
#  [Text(0.8253174071349626, -0.7272215463529821, 'Yes'),
#   Text(-0.8253173401114294, 0.7272216224174001, 'No')],
#  [Text(0.450173131164525, -0.39666629801071746, '99.2%'),
#   Text(-0.45017309460623417, 0.3966663395004, '0.8%')])

# %% [markdown]
# All cars have child safety locks

# %%
na_m = m_subtable['number_of_airbags'].value_counts()
plt.pie(na_m, labels=na_m.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca1e524fd0>,
# ...
#  [Text(-0.5274955919923943, -0.9652711538363682, '2.0'),
#   Text(0.8590076747875992, 0.6870995667703499, '0.0'),
#   Text(-0.42579141445343466, 1.014249314211128, '6.0'),
#   Text(-0.763427787416042, 0.7919457136704805, '1.0'),
#   Text(-0.82369110171777, 0.7290630761127369, '9.0')],
#  [Text(-0.28772486835948774, -0.5265115384562008, '56.3%'),
#   Text(0.46854964079323586, 0.37478158187473626, '31.1%'),
#   Text(-0.23224986242914614, 0.5532268986606153, '10.1%'),
#   Text(-0.41641515677238655, 0.4319703892748075, '1.7%'),
#   Text(-0.44928605548241995, 0.39767076878876556, '0.8%')])

# %% [markdown]
# Most cars have 2 airbags where as 10% cars have 6 airbags

# %%
ns_m = m_subtable['navigation_system'].value_counts()
plt.pie(ns_m, labels=ns_m.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca1fcf2c50>,
# ...
#  [Text(-0.5274955919923943, -0.9652711538363682, 'No'),
#   Text(0.5274955016171843, 0.9652712032240656, 'Yes')],
#  [Text(-0.28772486835948774, -0.5265115384562008, '56.3%'),
#   Text(0.28772481906391867, 0.5265115653949448, '43.7%')])

# %% [markdown]
# Healthy amount of cars have navigation system eventhough there is scope for improvement.

# %%
mo_m = m_subtable['model'].value_counts()
plt.pie(mo_m, labels=mo_m.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x79ca1e3bb490>,
# ...
#  [Text(-1.0924368087504164, 0.12877041153621535, 'Kuv100 Nxt'),
#   Text(-0.5777030406741208, -0.9360871737161424, 'Xuv500'),
#   Text(0.31651383467062355, -1.0534794694070204, 'Xuv300'),
#   Text(0.8041589625490694, -0.7505520388034428, 'Scorpio'),
#   Text(1.0501745216665939, -0.3273125021173819, 'Marazzo'),
#   Text(1.0951575458284815, 0.10310164797391755, 'Tuv300'),
#   Text(0.9965973362057137, 0.46561115694072014, 'Bolero Power Plus'),
#   Text(0.80195375201502, 0.752907816156156, 'Nuvosport'),
#   Text(0.5527918858486739, 0.9510105840314642, 'Bolero'),
#   Text(0.28547991729291977, 1.062309379052274, 'Xylo'),
#   Text(0.05644159467016483, 1.098551021296275, 'E Verito'),
#   Text(-0.11754832307264189, 1.0937012351381936, 'Verito Vibe'),
#   Text(-0.28859506280316727, 1.0614673286190377, 'Tuv300 Plus'),
#   Text(-0.4524159517423528, 1.0026563751400883, 'Thar'),
#   Text(-0.6049092381537611, 0.9187408849051165, 'Verito'),
# ...

# %% [markdown]
# Highest selling cars
# 1. KUV100 Nxt
# 2. Xuv500
# 3. XUV300
